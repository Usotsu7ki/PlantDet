# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from tensorflow.keras.optimizers import Adam, RMSprop
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications import InceptionResNetV2, EfficientNetV2L, Xception
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from keras import regularizers

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings
from keras.models import load_model
import itertools 
filterwarnings('ignore')
np.random.seed(101)
from sklearn.metrics import classification_report, confusion_matrix

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# Mon Dec 26 04:51:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
train_dir ="/content/drive/MyDrive/RiceLeaf/train"
val_dir = "/content/drive/MyDrive/RiceLeaf/validation"
test_dir="/content/drive/MyDrive/RiceLeaf/validation"
labels = ['bacterial_leaf_blight','brown_spot','healthy','leaf_blast','leaf_scald','narrow_brown_spot']
label_np=np.array(labels)

# %%
import tensorflow as tf
import numpy as np
import os
import random


def set_seed(seed):
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)


seed = 101
set_seed(seed)

# %%
model1 =  InceptionResNetV2(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
model2 = EfficientNetV2L(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
model3 = Xception(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
datagen_train = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=2,
                                  vertical_flip=False,
                                  horizontal_flip=True)

datagen_test = ImageDataGenerator(rescale=1./255)

datagen_val=ImageDataGenerator(rescale=1./255)

batch_size = 8
generator_train = datagen_train.flow_from_directory(directory=train_dir,
                                                    target_size=input_shape,
                                                    batch_size=batch_size,                                        
                                                    shuffle=True)

generator_val = datagen_val.flow_from_directory(directory=val_dir,
                                                  target_size=input_shape,
                                                  batch_size=batch_size,
                                                  shuffle=False)
generator_test=datagen_test.flow_from_directory(directory=test_dir,
                                                  target_size=input_shape,
                                                 batch_size=batch_size,
                                                 shuffle=False)
# Out:
# Found 2167 images belonging to 6 classes.
# Found 543 images belonging to 6 classes.
# Found 543 images belonging to 6 classes.

# %%
headModel = model1.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(6, activation="softmax")(headModel)
modelA = Model(inputs=model1.input, outputs=headModel)
modelA.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 35, 35, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 35, 35, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 35, 35, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 35, 35, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 35, 35, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 35, 35, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 35, 35, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 35, 35, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 35, 35, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 35, 35, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 35, 35, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 35, 35, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 35, 35, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 35, 35, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 35, 35, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 35, 35, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 35, 35, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 35, 35, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 35, 35, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 35, 35, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 35, 35, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 35, 35, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 35, 35, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 35, 35, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 35, 35, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 35, 35, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 35, 35, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 35, 35, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 35, 35, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 35, 35, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 35, 35, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 35, 35, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 35, 35, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 35, 35, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 35, 35, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 35, 35, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 35, 35, 32)  96          ['conv2d_57[0][0]']
#  ormalization)
#
# ...
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 8, 8, 256)   768         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 8, 8, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 8, 8, 192)   576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 8, 8, 224)   672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 8, 8, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 8, 8, 256)   768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 8, 8, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 8, 8, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 8, 8, 224)   672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 8, 8, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 8, 8, 256)   768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 8, 8, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 8, 8, 192)   576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 8, 8, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 8, 8, 224)   672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 8, 8, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 8, 8, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 8, 8, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 8, 8, 256)   768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 8, 8, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1536)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 512)          787456      ['dropout[0][0]']
#
#  batch_normalization_207 (Batch  (None, 512)         2048        ['dense[0][0]']
#  Normalization)
#
#  dense_1 (Dense)                (None, 256)          131584      ['batch_normalization_207[0][0]']
#
#  batch_normalization_208 (Batch  (None, 256)         1024        ['dense_1[0][0]']
#  Normalization)
#
#  dense_2 (Dense)                (None, 64)           16512       ['batch_normalization_208[0][0]']
#
#  dense_3 (Dense)                (None, 6)            390         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 55,275,750
# Trainable params: 55,213,670
# Non-trainable params: 62,080
# __________________________________________________________________________________________________

# %%
headModel = model2.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(6, activation="softmax")(headModel)
modelB = Model(inputs=model2.input, outputs=headModel)
modelB.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 299, 299, 3)  0           ['input_2[0][0]']
#
#  stem_conv (Conv2D)             (None, 150, 150, 32  864         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 150, 150, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 150, 150, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 150, 150, 32  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 150, 150, 32  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 150, 150, 32  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 150, 150, 32  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 150, 150, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 150, 150, 32  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_drop (Dropout)         (None, 150, 150, 32  0           ['block1c_project_activation[0][0
#                                 )                                ]']
#
#  block1c_add (Add)              (None, 150, 150, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1c_add[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_project_activation (Ac  (None, 150, 150, 32  0          ['block1d_project_bn[0][0]']
#  tivation)                      )
#
#  block1d_drop (Dropout)         (None, 150, 150, 32  0           ['block1d_project_activation[0][0
#                                 )                                ]']
#
#  block1d_add (Add)              (None, 150, 150, 32  0           ['block1d_drop[0][0]',
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 75, 75, 128)  36864       ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 75, 75, 128)  512        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 75, 75, 128)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 75, 75, 64)   8192        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 75, 75, 256)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 75, 75, 64)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 75, 75, 64)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 75, 75, 256)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 75, 75, 64)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 75, 75, 64)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 75, 75, 256)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 75, 75, 64)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 75, 75, 64)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 75, 75, 256)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 75, 75, 64)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 75, 75, 64)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 75, 75, 256)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2f_expand_activation[0][0]
#                                                                  ']
#
#  block2f_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 75, 75, 64)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 75, 75, 64)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 75, 75, 256)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2g_expand_activation[0][0]
#                                                                  ']
#
#  block2g_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 75, 75, 64)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 75, 75, 64)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 38, 38, 256)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 38, 38, 96)   24576       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 38, 38, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 38, 38, 96)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 38, 38, 96)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 38, 38, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 38, 38, 96)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 38, 38, 96)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 38, 38, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 38, 38, 96)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 38, 38, 96)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 38, 38, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_drop (Dropout)         (None, 38, 38, 96)   0           ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)              (None, 38, 38, 96)   0           ['block3e_drop[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3e_add[0][0]']
#
#  block3f_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3f_expand_conv[0][0]']
#  ization)
#
#  block3f_expand_activation (Act  (None, 38, 38, 384)  0          ['block3f_expand_bn[0][0]']
#  ivation)
#
#  block3f_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3f_expand_activation[0][0]
#                                                                  ']
#
#  block3f_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3f_project_conv[0][0]']
#  lization)
#
#  block3f_drop (Dropout)         (None, 38, 38, 96)   0           ['block3f_project_bn[0][0]']
#
#  block3f_add (Add)              (None, 38, 38, 96)   0           ['block3f_drop[0][0]',
#                                                                   'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3f_add[0][0]']
#
#  block3g_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3g_expand_conv[0][0]']
#  ization)
#
#  block3g_expand_activation (Act  (None, 38, 38, 384)  0          ['block3g_expand_bn[0][0]']
#  ivation)
#
#  block3g_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3g_expand_activation[0][0]
#                                                                  ']
#
#  block3g_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3g_project_conv[0][0]']
#  lization)
#
#  block3g_drop (Dropout)         (None, 38, 38, 96)   0           ['block3g_project_bn[0][0]']
#
#  block3g_add (Add)              (None, 38, 38, 96)   0           ['block3g_drop[0][0]',
#                                                                   'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 38, 38, 384)  36864       ['block3g_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 38, 38, 384)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 19, 19, 384)  3456       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 19, 19, 384)  1536       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 19, 19, 384)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 384)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 19, 19, 384)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 19, 19, 192)  73728       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 19, 19, 768)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 19, 19, 768)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 768)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 19, 19, 192)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 19, 19, 192)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 19, 19, 768)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 19, 19, 768)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 768)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 19, 19, 192)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 19, 19, 192)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 19, 19, 768)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 19, 19, 768)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 768)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 19, 19, 192)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 19, 19, 192)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4d_add[0][0]']
#
# ...
#
#  block7d_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 10, 10, 640)  0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 10, 10, 640)  0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7d_add[0][0]']
#                                 )
#
#  block7e_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7e_expand_conv[0][0]']
#  ization)                       )
#
#  block7e_expand_activation (Act  (None, 10, 10, 3840  0          ['block7e_expand_bn[0][0]']
#  ivation)                       )
#
#  block7e_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7e_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7e_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7e_dwconv2[0][0]']
#  )                              )
#
#  block7e_activation (Activation  (None, 10, 10, 3840  0          ['block7e_bn[0][0]']
#  )                              )
#
#  block7e_se_squeeze (GlobalAver  (None, 3840)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7e_activation[0][0]',
#                                 )                                 'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_drop (Dropout)         (None, 10, 10, 640)  0           ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)              (None, 10, 10, 640)  0           ['block7e_drop[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  block7f_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7e_add[0][0]']
#                                 )
#
#  block7f_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7f_expand_conv[0][0]']
#  ization)                       )
#
#  block7f_expand_activation (Act  (None, 10, 10, 3840  0          ['block7f_expand_bn[0][0]']
#  ivation)                       )
#
#  block7f_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7f_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7f_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7f_dwconv2[0][0]']
#  )                              )
#
#  block7f_activation (Activation  (None, 10, 10, 3840  0          ['block7f_bn[0][0]']
#  )                              )
#
#  block7f_se_squeeze (GlobalAver  (None, 3840)        0           ['block7f_activation[0][0]']
#  agePooling2D)
#
#  block7f_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7f_se_squeeze[0][0]']
#
#  block7f_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7f_se_reshape[0][0]']
#
#  block7f_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7f_se_reduce[0][0]']
#
#  block7f_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7f_activation[0][0]',
#                                 )                                 'block7f_se_expand[0][0]']
#
#  block7f_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7f_se_excite[0][0]']
#
#  block7f_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7f_project_conv[0][0]']
#  lization)
#
#  block7f_drop (Dropout)         (None, 10, 10, 640)  0           ['block7f_project_bn[0][0]']
#
#  block7f_add (Add)              (None, 10, 10, 640)  0           ['block7f_drop[0][0]',
#                                                                   'block7e_add[0][0]']
#
#  block7g_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7f_add[0][0]']
#                                 )
#
#  block7g_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7g_expand_conv[0][0]']
#  ization)                       )
#
#  block7g_expand_activation (Act  (None, 10, 10, 3840  0          ['block7g_expand_bn[0][0]']
#  ivation)                       )
#
#  block7g_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7g_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7g_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7g_dwconv2[0][0]']
#  )                              )
#
#  block7g_activation (Activation  (None, 10, 10, 3840  0          ['block7g_bn[0][0]']
#  )                              )
#
#  block7g_se_squeeze (GlobalAver  (None, 3840)        0           ['block7g_activation[0][0]']
#  agePooling2D)
#
#  block7g_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7g_se_squeeze[0][0]']
#
#  block7g_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7g_activation[0][0]',
#                                 )                                 'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7g_se_excite[0][0]']
#
#  block7g_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7g_project_conv[0][0]']
#  lization)
#
#  block7g_drop (Dropout)         (None, 10, 10, 640)  0           ['block7g_project_bn[0][0]']
#
#  block7g_add (Add)              (None, 10, 10, 640)  0           ['block7g_drop[0][0]',
#                                                                   'block7f_add[0][0]']
#
#  top_conv (Conv2D)              (None, 10, 10, 1280  819200      ['block7g_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 10, 10, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 10, 10, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  global_average_pooling2d_1 (Gl  (None, 1280)        0           ['top_activation[0][0]']
#  obalAveragePooling2D)
#
#  dropout_1 (Dropout)            (None, 1280)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 512)          656384      ['dropout_1[0][0]']
#
#  batch_normalization_209 (Batch  (None, 512)         2048        ['dense_4[0][0]']
#  Normalization)
#
#  dense_5 (Dense)                (None, 256)          131584      ['batch_normalization_209[0][0]']
#
#  batch_normalization_210 (Batch  (None, 256)         1024        ['dense_5[0][0]']
#  Normalization)
#
#  dense_6 (Dense)                (None, 64)           16512       ['batch_normalization_210[0][0]']
#
#  dense_7 (Dense)                (None, 6)            390         ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 118,554,790
# Trainable params: 118,040,678
# Non-trainable params: 514,112
# __________________________________________________________________________________________________

# %%
headModel = model3.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="PReLU", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(6, activation="softmax")(headModel)
modelC = Model(inputs=model3.input, outputs=headModel)
modelC.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_3[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 147, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 147, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 147, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 147, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_203 (Conv2D)            (None, 74, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 74, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_203 (Batch  (None, 74, 74, 128)  512        ['conv2d_203[0][0]']
#  Normalization)
#
#  add (Add)                      (None, 74, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_203[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 74, 74, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 74, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 74, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 74, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_204 (Conv2D)            (None, 37, 37, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 37, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_204 (Batch  (None, 37, 37, 256)  1024       ['conv2d_204[0][0]']
#  Normalization)
#
#  add_1 (Add)                    (None, 37, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_204[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 37, 37, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 37, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 37, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 37, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_205 (Conv2D)            (None, 19, 19, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 19, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_205 (Batch  (None, 19, 19, 728)  2912       ['conv2d_205[0][0]']
#  Normalization)
#
#  add_2 (Add)                    (None, 19, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_205[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 19, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 19, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 19, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 19, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 19, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 19, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 19, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 19, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 19, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 19, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_206 (Conv2D)            (None, 10, 10, 1024  745472      ['add_10[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 10, 10, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_206 (Batch  (None, 10, 10, 1024  4096       ['conv2d_206[0][0]']
#  Normalization)                 )
#
#  add_11 (Add)                   (None, 10, 10, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_206[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 10, 10, 1536  1582080    ['add_11[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 10, 10, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 10, 10, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 10, 10, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 10, 10, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 10, 10, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  obalAveragePooling2D)
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 512)          1049600     ['dropout_2[0][0]']
#
#  batch_normalization_211 (Batch  (None, 512)         2048        ['dense_8[0][0]']
#  Normalization)
#
#  dense_9 (Dense)                (None, 256)          131584      ['batch_normalization_211[0][0]']
#
#  batch_normalization_212 (Batch  (None, 256)         1024        ['dense_9[0][0]']
#  Normalization)
#
#  dense_10 (Dense)               (None, 64)           16512       ['batch_normalization_212[0][0]']
#
#  dense_11 (Dense)               (None, 6)            390         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 22,062,638
# Trainable params: 22,006,574
# Non-trainable params: 56,064
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
models = [modelA,modelB,modelC]
model_input = tf.keras.Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = tf.keras.layers.Average()(model_outputs)
ensemble_model = tf.keras.models.Model(inputs=model_input, outputs=ensemble_output, name='ensemble')
ensemble_model.summary()
# Out:
# Model: "ensemble"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  model (Functional)             (None, 6)            55275750    ['input_4[0][0]']
#
#  model_1 (Functional)           (None, 6)            118554790   ['input_4[0][0]']
#
#  model_2 (Functional)           (None, 6)            22062638    ['input_4[0][0]']
#
#  average (Average)              (None, 6)            0           ['model[0][0]',
#                                                                   'model_1[0][0]',
#                                                                   'model_2[0][0]']
#
# ==================================================================================================
# Total params: 195,893,178
# Trainable params: 195,260,922
# Non-trainable params: 632,256
# __________________________________________________________________________________________________

# %%
from keras import backend as K
def Recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def Precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def F1(y_true, y_pred):
    precision = Precision(y_true, y_pred)
    recall = Recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def Specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
optimizer = Adam(lr=1e-5)
loss = 'categorical_crossentropy'
metrics = ['accuracy', Precision, Recall, F1, Specificity]
ensemble_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
tf.keras.utils.plot_model(ensemble_model, 'model.png', show_shapes= True)

# %%
steps_per_epoch = generator_train.n / batch_size
steps_test = generator_test.n / batch_size

earlystopping = EarlyStopping(monitor ="val_loss", 
                              mode ="min", patience = 3, 
                              restore_best_weights = True)
history = ensemble_model.fit_generator(generator=generator_train,
                              epochs=50,
                              validation_data=generator_val,
                              validation_steps=steps_test,
                              callbacks =[earlystopping]
                              )
# Out:
# Epoch 1/50
# 271/271 [==============================] - 1718s 6s/step - loss: 1.7580 - accuracy: 0.2746 - Precision: 0.0720 - Recall: 0.0097 - F1: 0.0170 - Specificity: 0.9973 - val_loss: 1.5102 - val_accuracy: 0.4438 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_F1: 0.0000e+00 - val_Specificity: 1.0000
# Epoch 2/50
# 271/271 [==============================] - 394s 1s/step - loss: 1.4413 - accuracy: 0.4767 - Precision: 0.3770 - Recall: 0.0646 - F1: 0.1082 - Specificity: 0.9966 - val_loss: 1.0528 - val_accuracy: 0.7366 - val_Precision: 0.4926 - val_Recall: 0.2151 - val_F1: 0.2766 - val_Specificity: 0.9993
# Epoch 3/50
# 271/271 [==============================] - 396s 1s/step - loss: 1.1598 - accuracy: 0.6239 - Precision: 0.8102 - Recall: 0.2433 - F1: 0.3597 - Specificity: 0.9934 - val_loss: 0.8571 - val_accuracy: 0.7956 - val_Precision: 0.8566 - val_Recall: 0.4609 - val_F1: 0.5559 - val_Specificity: 0.9978
# Epoch 4/50
# 271/271 [==============================] - 397s 1s/step - loss: 1.0229 - accuracy: 0.6880 - Precision: 0.8602 - Recall: 0.3612 - F1: 0.4909 - Specificity: 0.9897 - val_loss: 0.7623 - val_accuracy: 0.8122 - val_Precision: 0.8870 - val_Recall: 0.5528 - val_F1: 0.6486 - val_Specificity: 0.9960
# Epoch 5/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.9058 - accuracy: 0.7296 - Precision: 0.8883 - Recall: 0.4588 - F1: 0.5878 - Specificity: 0.9888 - val_loss: 0.6749 - val_accuracy: 0.8306 - val_Precision: 0.9045 - val_Recall: 0.6263 - val_F1: 0.7104 - val_Specificity: 0.9960
# Epoch 6/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.8243 - accuracy: 0.7707 - Precision: 0.8972 - Recall: 0.5409 - F1: 0.6604 - Specificity: 0.9877 - val_loss: 0.6009 - val_accuracy: 0.8379 - val_Precision: 0.9002 - val_Recall: 0.6891 - val_F1: 0.7577 - val_Specificity: 0.9919
# Epoch 7/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.7471 - accuracy: 0.7813 - Precision: 0.8891 - Recall: 0.5916 - F1: 0.6978 - Specificity: 0.9852 - val_loss: 0.5137 - val_accuracy: 0.8674 - val_Precision: 0.9198 - val_Recall: 0.7445 - val_F1: 0.8039 - val_Specificity: 0.9908
# Epoch 8/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.6813 - accuracy: 0.7983 - Precision: 0.8965 - Recall: 0.6344 - F1: 0.7320 - Specificity: 0.9853 - val_loss: 0.4471 - val_accuracy: 0.8987 - val_Precision: 0.9398 - val_Recall: 0.7996 - val_F1: 0.8516 - val_Specificity: 0.9919
# Epoch 9/50
# 271/271 [==============================] - 400s 1s/step - loss: 0.6138 - accuracy: 0.8205 - Precision: 0.8957 - Recall: 0.6958 - F1: 0.7752 - Specificity: 0.9835 - val_loss: 0.4068 - val_accuracy: 0.8987 - val_Precision: 0.9375 - val_Recall: 0.8254 - val_F1: 0.8668 - val_Specificity: 0.9908
# Epoch 10/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.5442 - accuracy: 0.8436 - Precision: 0.9039 - Recall: 0.7375 - F1: 0.8057 - Specificity: 0.9846 - val_loss: 0.3723 - val_accuracy: 0.9153 - val_Precision: 0.9481 - val_Recall: 0.8548 - val_F1: 0.8886 - val_Specificity: 0.9915
# Epoch 11/50
# 271/271 [==============================] - 395s 1s/step - loss: 0.5176 - accuracy: 0.8417 - Precision: 0.9025 - Recall: 0.7494 - F1: 0.8128 - Specificity: 0.9837 - val_loss: 0.3509 - val_accuracy: 0.9190 - val_Precision: 0.9583 - val_Recall: 0.8713 - val_F1: 0.9039 - val_Specificity: 0.9930
# Epoch 12/50
# 271/271 [==============================] - 395s 1s/step - loss: 0.4661 - accuracy: 0.8754 - Precision: 0.9247 - Recall: 0.7918 - F1: 0.8478 - Specificity: 0.9873 - val_loss: 0.3058 - val_accuracy: 0.9282 - val_Precision: 0.9425 - val_Recall: 0.8860 - val_F1: 0.9101 - val_Specificity: 0.9901
# Epoch 13/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.4167 - accuracy: 0.8911 - Precision: 0.9196 - Recall: 0.8296 - F1: 0.8690 - Specificity: 0.9859 - val_loss: 0.2795 - val_accuracy: 0.9337 - val_Precision: 0.9499 - val_Recall: 0.9081 - val_F1: 0.9267 - val_Specificity: 0.9912
# Epoch 14/50
# 271/271 [==============================] - 398s 1s/step - loss: 0.4018 - accuracy: 0.8948 - Precision: 0.9295 - Recall: 0.8367 - F1: 0.8768 - Specificity: 0.9874 - val_loss: 0.2479 - val_accuracy: 0.9521 - val_Precision: 0.9617 - val_Recall: 0.9320 - val_F1: 0.9453 - val_Specificity: 0.9930
# Epoch 15/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.3540 - accuracy: 0.9128 - Precision: 0.9433 - Recall: 0.8584 - F1: 0.8960 - Specificity: 0.9895 - val_loss: 0.2284 - val_accuracy: 0.9448 - val_Precision: 0.9631 - val_Recall: 0.9338 - val_F1: 0.9465 - val_Specificity: 0.9930
# Epoch 16/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.3294 - accuracy: 0.9312 - Precision: 0.9520 - Recall: 0.8799 - F1: 0.9117 - Specificity: 0.9911 - val_loss: 0.1975 - val_accuracy: 0.9576 - val_Precision: 0.9623 - val_Recall: 0.9449 - val_F1: 0.9523 - val_Specificity: 0.9930
# Epoch 17/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.3220 - accuracy: 0.9243 - Precision: 0.9486 - Recall: 0.8823 - F1: 0.9116 - Specificity: 0.9908 - val_loss: 0.1737 - val_accuracy: 0.9632 - val_Precision: 0.9694 - val_Recall: 0.9596 - val_F1: 0.9640 - val_Specificity: 0.9941
# Epoch 18/50
# 271/271 [==============================] - 395s 1s/step - loss: 0.2834 - accuracy: 0.9317 - Precision: 0.9520 - Recall: 0.9008 - F1: 0.9235 - Specificity: 0.9910 - val_loss: 0.1762 - val_accuracy: 0.9632 - val_Precision: 0.9693 - val_Recall: 0.9577 - val_F1: 0.9630 - val_Specificity: 0.9941
# Epoch 19/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.2500 - accuracy: 0.9372 - Precision: 0.9550 - Recall: 0.9118 - F1: 0.9310 - Specificity: 0.9915 - val_loss: 0.1753 - val_accuracy: 0.9669 - val_Precision: 0.9680 - val_Recall: 0.9596 - val_F1: 0.9633 - val_Specificity: 0.9937
# Epoch 20/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.2327 - accuracy: 0.9423 - Precision: 0.9579 - Recall: 0.9276 - F1: 0.9413 - Specificity: 0.9920 - val_loss: 0.1637 - val_accuracy: 0.9687 - val_Precision: 0.9703 - val_Recall: 0.9651 - val_F1: 0.9675 - val_Specificity: 0.9941
# Epoch 21/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.2267 - accuracy: 0.9539 - Precision: 0.9662 - Recall: 0.9322 - F1: 0.9471 - Specificity: 0.9935 - val_loss: 0.1403 - val_accuracy: 0.9779 - val_Precision: 0.9795 - val_Recall: 0.9724 - val_F1: 0.9756 - val_Specificity: 0.9960
# Epoch 22/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.2106 - accuracy: 0.9599 - Precision: 0.9684 - Recall: 0.9421 - F1: 0.9540 - Specificity: 0.9939 - val_loss: 0.1438 - val_accuracy: 0.9761 - val_Precision: 0.9789 - val_Recall: 0.9688 - val_F1: 0.9734 - val_Specificity: 0.9960
# Epoch 23/50
# 271/271 [==============================] - 399s 1s/step - loss: 0.2120 - accuracy: 0.9557 - Precision: 0.9651 - Recall: 0.9423 - F1: 0.9527 - Specificity: 0.9932 - val_loss: 0.1298 - val_accuracy: 0.9797 - val_Precision: 0.9814 - val_Recall: 0.9706 - val_F1: 0.9755 - val_Specificity: 0.9963
# Epoch 24/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.2011 - accuracy: 0.9608 - Precision: 0.9676 - Recall: 0.9419 - F1: 0.9535 - Specificity: 0.9937 - val_loss: 0.1286 - val_accuracy: 0.9779 - val_Precision: 0.9816 - val_Recall: 0.9761 - val_F1: 0.9787 - val_Specificity: 0.9963
# Epoch 25/50
# 271/271 [==============================] - 397s 1s/step - loss: 0.1917 - accuracy: 0.9594 - Precision: 0.9746 - Recall: 0.9465 - F1: 0.9590 - Specificity: 0.9950 - val_loss: 0.1168 - val_accuracy: 0.9779 - val_Precision: 0.9777 - val_Recall: 0.9761 - val_F1: 0.9768 - val_Specificity: 0.9956
# Epoch 26/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.1762 - accuracy: 0.9714 - Precision: 0.9767 - Recall: 0.9585 - F1: 0.9669 - Specificity: 0.9955 - val_loss: 0.1111 - val_accuracy: 0.9834 - val_Precision: 0.9835 - val_Recall: 0.9798 - val_F1: 0.9815 - val_Specificity: 0.9967
# Epoch 27/50
# 271/271 [==============================] - 395s 1s/step - loss: 0.1597 - accuracy: 0.9709 - Precision: 0.9781 - Recall: 0.9616 - F1: 0.9691 - Specificity: 0.9957 - val_loss: 0.1184 - val_accuracy: 0.9779 - val_Precision: 0.9777 - val_Recall: 0.9743 - val_F1: 0.9759 - val_Specificity: 0.9956
# Epoch 28/50
# 271/271 [==============================] - 398s 1s/step - loss: 0.1584 - accuracy: 0.9709 - Precision: 0.9775 - Recall: 0.9613 - F1: 0.9686 - Specificity: 0.9957 - val_loss: 0.1059 - val_accuracy: 0.9816 - val_Precision: 0.9816 - val_Recall: 0.9816 - val_F1: 0.9816 - val_Specificity: 0.9963
# Epoch 29/50
# 271/271 [==============================] - 396s 1s/step - loss: 0.1441 - accuracy: 0.9732 - Precision: 0.9807 - Recall: 0.9626 - F1: 0.9705 - Specificity: 0.9962 - val_loss: 0.0920 - val_accuracy: 0.9816 - val_Precision: 0.9816 - val_Recall: 0.9816 - val_F1: 0.9816 - val_Specificity: 0.9963
# Epoch 30/50
# 271/271 [==============================] - 400s 1s/step - loss: 0.1327 - accuracy: 0.9797 - Precision: 0.9832 - Recall: 0.9714 - F1: 0.9768 - Specificity: 0.9967 - val_loss: 0.1040 - val_accuracy: 0.9779 - val_Precision: 0.9777 - val_Recall: 0.9761 - val_F1: 0.9768 - val_Specificity: 0.9956
# Epoch 31/50
# 271/271 [==============================] - 404s 1s/step - loss: 0.1401 - accuracy: 0.9746 - Precision: 0.9782 - Recall: 0.9677 - F1: 0.9724 - Specificity: 0.9958 - val_loss: 0.1044 - val_accuracy: 0.9797 - val_Precision: 0.9795 - val_Recall: 0.9779 - val_F1: 0.9787 - val_Specificity: 0.9960
# Epoch 32/50
# 271/271 [==============================] - 402s 1s/step - loss: 0.1260 - accuracy: 0.9802 - Precision: 0.9855 - Recall: 0.9732 - F1: 0.9788 - Specificity: 0.9971 - val_loss: 0.1021 - val_accuracy: 0.9853 - val_Precision: 0.9850 - val_Recall: 0.9835 - val_F1: 0.9842 - val_Specificity: 0.9971

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
Y_pred = ensemble_model.predict_generator(generator_test)
y_pred = np.argmax(Y_pred, axis=1)
array = confusion_matrix(generator_test.classes, y_pred)
df_cm = pd.DataFrame(array, index =['bacterial_leaf_blight','brown_spot','healthy','leaf_blast','leaf_scald','narrow_brown_spot'],
                  columns = ['bacterial_leaf_blight','brown_spot','healthy','leaf_blast','leaf_scald','narrow_brown_spot'])
plt.figure(figsize=(10,10))
sn.set(font_scale=2)
sn.heatmap(df_cm, annot=True, cmap='summer', fmt='g')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('model1_confusion',dpi=200); 
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()

for i, met in enumerate(['Precision', 'Recall']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'])

fig.savefig('model1_Precision_Recall_',dpi=1200);

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()
for i, met in enumerate([ 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'],loc='best')

fig.savefig('model1_accuracy_loss',dpi=1200); 

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()
for i, met in enumerate([ 'F1','Specificity']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'],loc='best')

fig.savefig('model1_F1_Specificity',dpi=1200); 

plt.show()
