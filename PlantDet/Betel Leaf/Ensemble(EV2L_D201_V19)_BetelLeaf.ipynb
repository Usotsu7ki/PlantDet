# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from tensorflow.keras.optimizers import Adam, RMSprop
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications import EfficientNetV2L, DenseNet201, VGG19
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from keras import regularizers

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings
from keras.models import load_model
import itertools 
filterwarnings('ignore')
np.random.seed(101)
from sklearn.metrics import classification_report, confusion_matrix

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# Sat Dec 17 15:51:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0    27W /  70W |  14592MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
train_dir ="/content/drive/MyDrive/Betel Leaf/Train"
val_dir = "/content/drive/MyDrive/Betel Leaf/Test"
test_dir="/content/drive/MyDrive/Betel Leaf/Test"
labels = ['Healthy Betel Leaf','Unhealthy Betel Leaf']
label_np=np.array(labels)

# %%
import tensorflow as tf
import numpy as np
import os
import random


def set_seed(seed):
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)


seed = 101
set_seed(seed)

# %%
model1 = EfficientNetV2L(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
model2 = DenseNet201(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
model3 = VGG19(include_top=False,input_shape=(299, 299,3), weights='imagenet')
input_shape = (299, 299)

# %%
datagen_train = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=2,
                                  vertical_flip=False,
                                  horizontal_flip=True)

datagen_test = ImageDataGenerator(rescale=1./255)

datagen_val=ImageDataGenerator(rescale=1./255)

batch_size = 4
generator_train = datagen_train.flow_from_directory(directory=train_dir,
                                                    target_size=input_shape,
                                                    batch_size=batch_size,                                        
                                                    shuffle=True)

generator_val = datagen_val.flow_from_directory(directory=val_dir,
                                                  target_size=input_shape,
                                                  batch_size=batch_size,
                                                  shuffle=False)
generator_test=datagen_test.flow_from_directory(directory=test_dir,
                                                  target_size=input_shape,
                                                 batch_size=batch_size,
                                                 shuffle=False)
# Out:
# Found 800 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
headModel = model1.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(2, activation="sigmoid")(headModel)
modelA = Model(inputs=model1.input, outputs=headModel)
modelA.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 299, 299, 3)  0           ['input_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 150, 150, 32  864         ['rescaling_1[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 150, 150, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 150, 150, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 150, 150, 32  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 150, 150, 32  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 150, 150, 32  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 150, 150, 32  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 150, 150, 32  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 150, 150, 32  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_drop (Dropout)         (None, 150, 150, 32  0           ['block1c_project_activation[0][0
#                                 )                                ]']
#
#  block1c_add (Add)              (None, 150, 150, 32  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 150, 150, 32  9216        ['block1c_add[0][0]']
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 150, 150, 32  128        ['block1d_project_conv[0][0]']
#  lization)                      )
#
#  block1d_project_activation (Ac  (None, 150, 150, 32  0          ['block1d_project_bn[0][0]']
#  tivation)                      )
#
#  block1d_drop (Dropout)         (None, 150, 150, 32  0           ['block1d_project_activation[0][0
#                                 )                                ]']
#
#  block1d_add (Add)              (None, 150, 150, 32  0           ['block1d_drop[0][0]',
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 75, 75, 128)  36864       ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 75, 75, 128)  512        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 75, 75, 128)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 75, 75, 64)   8192        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 75, 75, 256)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 75, 75, 64)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 75, 75, 64)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 75, 75, 256)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 75, 75, 64)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 75, 75, 64)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 75, 75, 256)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 75, 75, 64)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 75, 75, 64)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 75, 75, 256)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 75, 75, 64)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 75, 75, 64)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 75, 75, 256)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2f_expand_activation[0][0]
#                                                                  ']
#
#  block2f_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 75, 75, 64)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 75, 75, 64)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 75, 75, 256)  147456      ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 75, 75, 256)  1024       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 75, 75, 256)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_project_conv (Conv2D)  (None, 75, 75, 64)   16384       ['block2g_expand_activation[0][0]
#                                                                  ']
#
#  block2g_project_bn (BatchNorma  (None, 75, 75, 64)  256         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 75, 75, 64)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 75, 75, 64)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 38, 38, 256)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 38, 38, 96)   24576       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 38, 38, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 38, 38, 96)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 38, 38, 96)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 38, 38, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 38, 38, 96)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 38, 38, 96)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 38, 38, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 38, 38, 96)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 38, 38, 96)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 38, 38, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_drop (Dropout)         (None, 38, 38, 96)   0           ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)              (None, 38, 38, 96)   0           ['block3e_drop[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3e_add[0][0]']
#
#  block3f_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3f_expand_conv[0][0]']
#  ization)
#
#  block3f_expand_activation (Act  (None, 38, 38, 384)  0          ['block3f_expand_bn[0][0]']
#  ivation)
#
#  block3f_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3f_expand_activation[0][0]
#                                                                  ']
#
#  block3f_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3f_project_conv[0][0]']
#  lization)
#
#  block3f_drop (Dropout)         (None, 38, 38, 96)   0           ['block3f_project_bn[0][0]']
#
#  block3f_add (Add)              (None, 38, 38, 96)   0           ['block3f_drop[0][0]',
#                                                                   'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2D)   (None, 38, 38, 384)  331776      ['block3f_add[0][0]']
#
#  block3g_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block3g_expand_conv[0][0]']
#  ization)
#
#  block3g_expand_activation (Act  (None, 38, 38, 384)  0          ['block3g_expand_bn[0][0]']
#  ivation)
#
#  block3g_project_conv (Conv2D)  (None, 38, 38, 96)   36864       ['block3g_expand_activation[0][0]
#                                                                  ']
#
#  block3g_project_bn (BatchNorma  (None, 38, 38, 96)  384         ['block3g_project_conv[0][0]']
#  lization)
#
#  block3g_drop (Dropout)         (None, 38, 38, 96)   0           ['block3g_project_bn[0][0]']
#
#  block3g_add (Add)              (None, 38, 38, 96)   0           ['block3g_drop[0][0]',
#                                                                   'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 38, 38, 384)  36864       ['block3g_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 38, 38, 384)  1536       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 38, 38, 384)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 19, 19, 384)  3456       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 19, 19, 384)  1536       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 19, 19, 384)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 384)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 19, 19, 384)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 19, 19, 192)  73728       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 19, 19, 768)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 19, 19, 768)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 768)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 19, 19, 192)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 19, 19, 192)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 19, 19, 768)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 19, 19, 768)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 768)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 19, 19, 192)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 19, 19, 192)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 19, 19, 768)  3072       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 19, 19, 768)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 19, 19, 768)  6912       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 19, 19, 768)  3072       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 19, 19, 768)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 768)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 19, 19, 768)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 19, 19, 192)  147456      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 19, 19, 192)  768        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 19, 19, 192)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 19, 19, 192)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 19, 19, 768)  147456      ['block4d_add[0][0]']
#
# ...
#
#  block7c_drop (Dropout)         (None, 10, 10, 640)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 10, 10, 640)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7c_add[0][0]']
#                                 )
#
#  block7d_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7d_expand_conv[0][0]']
#  ization)                       )
#
#  block7d_expand_activation (Act  (None, 10, 10, 3840  0          ['block7d_expand_bn[0][0]']
#  ivation)                       )
#
#  block7d_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7d_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7d_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7d_dwconv2[0][0]']
#  )                              )
#
#  block7d_activation (Activation  (None, 10, 10, 3840  0          ['block7d_bn[0][0]']
#  )                              )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7d_activation[0][0]',
#                                 )                                 'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 10, 10, 640)  0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 10, 10, 640)  0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7d_add[0][0]']
#                                 )
#
#  block7e_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7e_expand_conv[0][0]']
#  ization)                       )
#
#  block7e_expand_activation (Act  (None, 10, 10, 3840  0          ['block7e_expand_bn[0][0]']
#  ivation)                       )
#
#  block7e_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7e_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7e_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7e_dwconv2[0][0]']
#  )                              )
#
#  block7e_activation (Activation  (None, 10, 10, 3840  0          ['block7e_bn[0][0]']
#  )                              )
#
#  block7e_se_squeeze (GlobalAver  (None, 3840)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7e_activation[0][0]',
#                                 )                                 'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_drop (Dropout)         (None, 10, 10, 640)  0           ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)              (None, 10, 10, 640)  0           ['block7e_drop[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  block7f_expand_conv (Conv2D)   (None, 10, 10, 3840  2457600     ['block7e_add[0][0]']
#                                 )
#
#  block7f_expand_bn (BatchNormal  (None, 10, 10, 3840  15360      ['block7f_expand_conv[0][0]']
#  ization)                       )
#
#  block7f_expand_activation (Act  (None, 10, 10, 3840  0          ['block7f_expand_bn[0][0]']
#  ivation)                       )
#
#  block7g_expand_activation (Act  (None, 10, 10, 3840  0          ['block7g_expand_bn[0][0]']
#  ivation)                       )
#
#  block7g_dwconv2 (DepthwiseConv  (None, 10, 10, 3840  34560      ['block7g_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7g_bn (BatchNormalization  (None, 10, 10, 3840  15360      ['block7g_dwconv2[0][0]']
#  )                              )
#
#  block7g_activation (Activation  (None, 10, 10, 3840  0          ['block7g_bn[0][0]']
#  )                              )
#
#  block7g_se_squeeze (GlobalAver  (None, 3840)        0           ['block7g_activation[0][0]']
#  agePooling2D)
#
#  block7g_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7g_se_squeeze[0][0]']
#
#  block7g_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multiply)   (None, 10, 10, 3840  0           ['block7g_activation[0][0]',
#                                 )                                 'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv2D)  (None, 10, 10, 640)  2457600     ['block7g_se_excite[0][0]']
#
#  block7g_project_bn (BatchNorma  (None, 10, 10, 640)  2560       ['block7g_project_conv[0][0]']
#  lization)
#
#  block7g_drop (Dropout)         (None, 10, 10, 640)  0           ['block7g_project_bn[0][0]']
#
#  block7g_add (Add)              (None, 10, 10, 640)  0           ['block7g_drop[0][0]',
#                                                                   'block7f_add[0][0]']
#
#  top_conv (Conv2D)              (None, 10, 10, 1280  819200      ['block7g_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 10, 10, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 10, 10, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  global_average_pooling2d_6 (Gl  (None, 1280)        0           ['top_activation[0][0]']
#  obalAveragePooling2D)
#
#  dropout_6 (Dropout)            (None, 1280)         0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_24 (Dense)               (None, 512)          655872      ['dropout_6[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 512)         2048        ['dense_24[0][0]']
#  ormalization)
#
#  dense_25 (Dense)               (None, 256)          131328      ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 256)         1024        ['dense_25[0][0]']
#  ormalization)
#
#  dense_26 (Dense)               (None, 64)           16448       ['batch_normalization_13[0][0]']
#
#  dense_27 (Dense)               (None, 2)            130         ['dense_26[0][0]']
#
# ==================================================================================================
# Total params: 118,553,698
# Trainable params: 118,039,586
# Non-trainable params: 514,112
# __________________________________________________________________________________________________

# %%
headModel = model2.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(2, activation="sigmoid")(headModel)
modelB = Model(inputs=model2.input, outputs=headModel)
modelB.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 305, 305, 3)  0          ['input_6[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 150, 150, 64  9408        ['zero_padding2d_2[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 150, 150, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 150, 150, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 152, 152, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 75, 75, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 75, 75, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 75, 75, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 75, 75, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 75, 75, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 75, 75, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 75, 75, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 75, 75, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 75, 75, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 75, 75, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 75, 75, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 75, 75, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 75, 75, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 75, 75, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 75, 75, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 75, 75, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 75, 75, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 75, 75, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 75, 75, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 75, 75, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 75, 75, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 75, 75, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 75, 75, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 75, 75, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 75, 75, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 75, 75, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 37, 37, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 37, 37, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 37, 37, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 37, 37, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 37, 37, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 37, 37, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 37, 37, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 37, 37, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 37, 37, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 37, 37, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 37, 37, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 37, 37, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 37, 37, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 37, 37, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 37, 37, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 37, 37, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 37, 37, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 37, 37, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 37, 37, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 37, 37, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 37, 37, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 37, 37, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 37, 37, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 37, 37, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 37, 37, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 37, 37, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 37, 37, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 37, 37, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 37, 37, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 37, 37, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 37, 37, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 37, 37, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 37, 37, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 37, 37, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 37, 37, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 37, 37, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 37, 37, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 37, 37, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 37, 37, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 37, 37, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 37, 37, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 37, 37, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 37, 37, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 37, 37, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 37, 37, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 37, 37, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 37, 37, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 37, 37, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 37, 37, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 37, 37, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 37, 37, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 18, 18, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 18, 18, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 18, 18, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 18, 18, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 18, 18, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 18, 18, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 18, 18, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 18, 18, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 18, 18, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 18, 18, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 18, 18, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 18, 18, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 18, 18, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 18, 18, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 18, 18, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 18, 18, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
# ...
#
#  conv5_block26_0_bn (BatchNorma  (None, 9, 9, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 9, 9, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 9, 9, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 9, 9, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 9, 9, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 9, 9, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 9, 9, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 9, 9, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 9, 9, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 9, 9, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 9, 9, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 9, 9, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 9, 9, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 9, 9, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 9, 9, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 9, 9, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 9, 9, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 9, 9, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 9, 9, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 9, 9, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 9, 9, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 9, 9, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 9, 9, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 9, 9, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 9, 9, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 9, 9, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 9, 9, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 9, 9, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 9, 9, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 9, 9, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 1920)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  dropout_7 (Dropout)            (None, 1920)         0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  dense_28 (Dense)               (None, 512)          983552      ['dropout_7[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 512)         2048        ['dense_28[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 256)          131328      ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 256)         1024        ['dense_29[0][0]']
#  ormalization)
#
#  dense_30 (Dense)               (None, 64)           16448       ['batch_normalization_15[0][0]']
#
#  dense_31 (Dense)               (None, 2)            130         ['dense_30[0][0]']
#
# ==================================================================================================
# Total params: 19,456,514
# Trainable params: 19,225,922
# Non-trainable params: 230,592
# __________________________________________________________________________________________________

# %%
headModel = model3.output
headModel = layers.GlobalAveragePooling2D()(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(512, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = layers.BatchNormalization()(headModel)
headModel = Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.00001))(headModel)
headModel = Dense(2, activation="sigmoid")(headModel)
modelC = Model(inputs=model3.input, outputs=headModel)
modelC.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 299, 299, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 299, 299, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 149, 149, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 149, 149, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 149, 149, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 74, 74, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 37, 37, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 18, 18, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  global_average_pooling2d_8   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_32 (Dense)            (None, 512)               262656
#
#  batch_normalization_16 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_33 (Dense)            (None, 256)               131328
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_34 (Dense)            (None, 64)                16448
#
#  dense_35 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 20,438,018
# Trainable params: 20,436,482
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
import tensorflow as tf
models = [modelA,modelB,modelC]
model_input = tf.keras.Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = tf.keras.layers.Average()(model_outputs)
ensemble_model = tf.keras.models.Model(inputs=model_input, outputs=ensemble_output, name='ensemble')
ensemble_model.summary()
# Out:
# Model: "ensemble"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  model_6 (Functional)           (None, 2)            118553698   ['input_9[0][0]']
#
#  model_7 (Functional)           (None, 2)            19456514    ['input_9[0][0]']
#
#  model_8 (Functional)           (None, 2)            20438018    ['input_9[0][0]']
#
#  average_2 (Average)            (None, 2)            0           ['model_6[0][0]',
#                                                                   'model_7[0][0]',
#                                                                   'model_8[0][0]']
#
# ==================================================================================================
# Total params: 158,448,230
# Trainable params: 157,701,990
# Non-trainable params: 746,240
# __________________________________________________________________________________________________

# %%
from keras import backend as K
def Recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def Precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def F1(y_true, y_pred):
    precision = Precision(y_true, y_pred)
    recall = Recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def Specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
optimizer = Adam(lr=1e-5)
loss = 'categorical_crossentropy'
metrics = ['accuracy', Precision, Recall, F1, Specificity]
ensemble_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
tf.keras.utils.plot_model(ensemble_model, 'model.png', show_shapes= True)

# %%
steps_per_epoch = generator_train.n / batch_size
steps_test = generator_test.n / batch_size

earlystopping = EarlyStopping(monitor ="val_loss", 
                              mode ="min", patience = 3, 
                              restore_best_weights = True)
history = ensemble_model.fit_generator(generator=generator_train,
                              epochs=50,
                              validation_data=generator_val,
                              validation_steps=steps_test,
                              callbacks =[earlystopping]
                              )
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1308s 6s/step - loss: 0.7174 - accuracy: 0.5550 - Precision: 0.5473 - Recall: 0.4800 - F1: 0.5023 - Specificity: 0.5950 - val_loss: 0.7101 - val_accuracy: 0.5550 - val_Precision: 0.5700 - val_Recall: 0.6350 - val_F1: 0.5960 - val_Specificity: 0.4950
# Epoch 2/50
# 200/200 [==============================] - 274s 1s/step - loss: 0.6942 - accuracy: 0.6037 - Precision: 0.6240 - Recall: 0.5450 - F1: 0.5694 - Specificity: 0.6538 - val_loss: 0.6703 - val_accuracy: 0.6150 - val_Precision: 0.6412 - val_Recall: 0.8450 - val_F1: 0.7186 - val_Specificity: 0.4600
# Epoch 3/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.6360 - accuracy: 0.6888 - Precision: 0.6908 - Recall: 0.6200 - F1: 0.6388 - Specificity: 0.7075 - val_loss: 0.6200 - val_accuracy: 0.7400 - val_Precision: 0.7128 - val_Recall: 0.8000 - val_F1: 0.7490 - val_Specificity: 0.6500
# Epoch 4/50
# 200/200 [==============================] - 274s 1s/step - loss: 0.6135 - accuracy: 0.7250 - Precision: 0.7118 - Recall: 0.6575 - F1: 0.6740 - Specificity: 0.7262 - val_loss: 0.6106 - val_accuracy: 0.7050 - val_Precision: 0.7020 - val_Recall: 0.7550 - val_F1: 0.7216 - val_Specificity: 0.6600
# Epoch 5/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.5659 - accuracy: 0.7962 - Precision: 0.7922 - Recall: 0.7188 - F1: 0.7404 - Specificity: 0.8012 - val_loss: 0.5443 - val_accuracy: 0.8250 - val_Precision: 0.8101 - val_Recall: 0.8600 - val_F1: 0.8299 - val_Specificity: 0.7650
# Epoch 6/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.5300 - accuracy: 0.8175 - Precision: 0.8083 - Recall: 0.7550 - F1: 0.7711 - Specificity: 0.8125 - val_loss: 0.4942 - val_accuracy: 0.8750 - val_Precision: 0.8530 - val_Recall: 0.8850 - val_F1: 0.8656 - val_Specificity: 0.8350
# Epoch 7/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.4994 - accuracy: 0.8275 - Precision: 0.8486 - Recall: 0.7738 - F1: 0.7989 - Specificity: 0.8575 - val_loss: 0.4571 - val_accuracy: 0.9100 - val_Precision: 0.9050 - val_Recall: 0.8950 - val_F1: 0.8956 - val_Specificity: 0.9050
# Epoch 8/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.4588 - accuracy: 0.8562 - Precision: 0.8665 - Recall: 0.8087 - F1: 0.8295 - Specificity: 0.8737 - val_loss: 0.3629 - val_accuracy: 0.9050 - val_Precision: 0.9733 - val_Recall: 0.7650 - val_F1: 0.8305 - val_Specificity: 0.9950
# Epoch 9/50
# 200/200 [==============================] - 274s 1s/step - loss: 0.4494 - accuracy: 0.8650 - Precision: 0.8747 - Recall: 0.8200 - F1: 0.8383 - Specificity: 0.8813 - val_loss: 0.4115 - val_accuracy: 0.9250 - val_Precision: 0.9280 - val_Recall: 0.9100 - val_F1: 0.9159 - val_Specificity: 0.9250
# Epoch 10/50
# 200/200 [==============================] - 276s 1s/step - loss: 0.4106 - accuracy: 0.9050 - Precision: 0.9070 - Recall: 0.8400 - F1: 0.8652 - Specificity: 0.9112 - val_loss: 0.3236 - val_accuracy: 0.9850 - val_Precision: 0.9933 - val_Recall: 0.9700 - val_F1: 0.9800 - val_Specificity: 0.9950
# Epoch 11/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.4142 - accuracy: 0.8875 - Precision: 0.8908 - Recall: 0.8188 - F1: 0.8466 - Specificity: 0.9000 - val_loss: 0.3248 - val_accuracy: 0.9800 - val_Precision: 0.9793 - val_Recall: 0.9750 - val_F1: 0.9763 - val_Specificity: 0.9800
# Epoch 12/50
# 200/200 [==============================] - 276s 1s/step - loss: 0.3761 - accuracy: 0.9137 - Precision: 0.9225 - Recall: 0.8763 - F1: 0.8944 - Specificity: 0.9287 - val_loss: 0.3190 - val_accuracy: 0.9800 - val_Precision: 0.9850 - val_Recall: 0.9750 - val_F1: 0.9793 - val_Specificity: 0.9850
# Epoch 13/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.3841 - accuracy: 0.9038 - Precision: 0.9099 - Recall: 0.8675 - F1: 0.8832 - Specificity: 0.9137 - val_loss: 0.2684 - val_accuracy: 0.9900 - val_Precision: 0.9950 - val_Recall: 0.9750 - val_F1: 0.9836 - val_Specificity: 0.9950
# Epoch 14/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.3992 - accuracy: 0.8750 - Precision: 0.8900 - Recall: 0.8300 - F1: 0.8539 - Specificity: 0.8988 - val_loss: 0.2475 - val_accuracy: 0.9850 - val_Precision: 0.9960 - val_Recall: 0.9750 - val_F1: 0.9825 - val_Specificity: 0.9950
# Epoch 15/50
# 200/200 [==============================] - 274s 1s/step - loss: 0.3764 - accuracy: 0.9075 - Precision: 0.9143 - Recall: 0.8512 - F1: 0.8753 - Specificity: 0.9200 - val_loss: 0.2506 - val_accuracy: 0.9900 - val_Precision: 1.0000 - val_Recall: 0.9650 - val_F1: 0.9800 - val_Specificity: 1.0000
# Epoch 16/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.3851 - accuracy: 0.8888 - Precision: 0.8979 - Recall: 0.8288 - F1: 0.8565 - Specificity: 0.9100 - val_loss: 0.2285 - val_accuracy: 0.9950 - val_Precision: 1.0000 - val_Recall: 0.9650 - val_F1: 0.9800 - val_Specificity: 1.0000
# Epoch 17/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.3503 - accuracy: 0.9200 - Precision: 0.9322 - Recall: 0.8612 - F1: 0.8900 - Specificity: 0.9475 - val_loss: 0.2283 - val_accuracy: 0.9800 - val_Precision: 0.9950 - val_Recall: 0.9650 - val_F1: 0.9779 - val_Specificity: 0.9950
# Epoch 18/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.3430 - accuracy: 0.9200 - Precision: 0.9261 - Recall: 0.8687 - F1: 0.8917 - Specificity: 0.9375 - val_loss: 0.2266 - val_accuracy: 0.9900 - val_Precision: 0.9883 - val_Recall: 0.9650 - val_F1: 0.9750 - val_Specificity: 0.9900
# Epoch 19/50
# 200/200 [==============================] - 276s 1s/step - loss: 0.3291 - accuracy: 0.9175 - Precision: 0.9263 - Recall: 0.8725 - F1: 0.8946 - Specificity: 0.9450 - val_loss: 0.2575 - val_accuracy: 0.9850 - val_Precision: 0.9900 - val_Recall: 0.9750 - val_F1: 0.9814 - val_Specificity: 0.9900
# Epoch 20/50
# 200/200 [==============================] - 275s 1s/step - loss: 0.3241 - accuracy: 0.9212 - Precision: 0.9227 - Recall: 0.8675 - F1: 0.8901 - Specificity: 0.9350 - val_loss: 0.2915 - val_accuracy: 0.9600 - val_Precision: 0.9623 - val_Recall: 0.9700 - val_F1: 0.9653 - val_Specificity: 0.9600
# Epoch 21/50
# 200/200 [==============================] - 277s 1s/step - loss: 0.3387 - accuracy: 0.8950 - Precision: 0.9105 - Recall: 0.8238 - F1: 0.8575 - Specificity: 0.9400 - val_loss: 0.2377 - val_accuracy: 0.9850 - val_Precision: 1.0000 - val_Recall: 0.9700 - val_F1: 0.9829 - val_Specificity: 1.0000

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
Y_pred = ensemble_model.predict_generator(generator_test)
y_pred = np.argmax(Y_pred, axis=1)
array = confusion_matrix(generator_test.classes, y_pred)
df_cm = pd.DataFrame(array, index =['Healthy Betel Leaf','Unhealthy Betel Leaf'],
                  columns = ['Healthy Betel Leaf','Unhealthy Betel Leaf'])
plt.figure(figsize=(10,10))
sn.set(font_scale=2)
sn.heatmap(df_cm, annot=True, cmap='summer', fmt='g')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('model1_confusion',dpi=200); 
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()

for i, met in enumerate(['Precision', 'Recall']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'])

fig.savefig('model1_Precision_Recall_',dpi=1200);

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()
for i, met in enumerate([ 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'],loc='best')

fig.savefig('model1_accuracy_loss',dpi=1200); 

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 5))
ax = ax.ravel()
for i, met in enumerate([ 'F1','Specificity']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].grid(color = '#e0e0eb')
    ax[i].legend(['train', 'val'],loc='best')

fig.savefig('model1_F1_Specificity',dpi=1200); 

plt.show()
